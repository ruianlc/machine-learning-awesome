# %% [markdown]
# # 使用Faker工具包生产虚拟数据

# %% [markdown]
# ## 导入依赖库

# %%
from faker import Faker
#Faker.seed(42) # fake记录可重复

# %% [markdown]
# ## 定义Faker对象

# %%
#fake = Faker()
fake = Faker('zh_CN') # 本地化

# %% [markdown]
# ## 生成Fake数据

# %% [markdown]
# ### 生成人物属性信息

# %% [markdown]
# 生成单条记录：

# %%
fake.profile()
# Out:
# {'job': '房地产投资分析',
#  'company': '鑫博腾飞信息有限公司',
#  'ssn': '320382198212182187',
#  'residence': '宁夏回族自治区重庆市翔安拉萨路C座 302654',
#  'current_location': (Decimal('-32.2021525'), Decimal('0.707823')),
#  'blood_group': 'A-',
#  'website': ['https://www.ming.cn/'],
#  'username': 'xiaoli',
#  'name': '何淑珍',
#  'sex': 'F',
#  'address': '山东省长春市牧野西安路D座 225534',
#  'mail': 'xiakong@gmail.com',
#  'birthdate': datetime.date(1969, 10, 31)}

# %% [markdown]
# 批量生成多条记录：

# %%
import pprint
for _ in range(3):
    pprint.pprint(fake.profile())
# Out:
# {'address': '5638 Peter Vista\nPort Daniel, PA 79915',
#  'birthdate': datetime.date(1929, 1, 7),
#  'blood_group': 'O-',
#  'company': 'Rubio, Thomas and Esparza',
#  'current_location': (Decimal('12.1798255'), Decimal('64.038968')),
#  'job': 'Field seismologist',
#  'mail': 'frobles@yahoo.com',
#  'name': 'Suzanne Gonzalez',
#  'residence': '2636 Henson Plains\nNorth Rhondahaven, VA 89631',
#  'sex': 'F',
#  'ssn': '239-70-9220',
#  'username': 'fmunoz',
#  'website': ['http://stone.info/',
#              'https://martinez.biz/',
#              'https://www.hayes.biz/']}
# {'address': '44827 Brown Port\nGriffinbury, LA 71638',
#  'birthdate': datetime.date(1954, 5, 24),
#  'blood_group': 'AB+',
#  'company': 'Farley Inc',
#  'current_location': (Decimal('-26.1911585'), Decimal('54.711192')),
#  'job': 'Therapist, drama',
#  'mail': 'bjohnson@hotmail.com',
#  'name': 'Jonathan Mason',
#  'residence': '2513 Michael Landing\nJenniferfort, IN 08371',
#  'sex': 'M',
# ...

# %% [markdown]
# ### 生成Dataframe

# %%
import pandas as pd

df_fake = pd.DataFrame([fake.profile() for _ in range(10)])
df_fake
# Out:
#                                     job                         company  \
# 0                           Optometrist                Stephens-Schultz
# 1                          Tour manager    Rodriguez, Pearson and Rivas
# 2                            Air broker       Hoover, Gordon and Parker
# 3       Television production assistant                  Campbell-Davis
# 4                   Information officer                        Webb Inc
# 5                         Archaeologist                     Wilson-Ward
# 6                    Investment analyst      Jackson, Flowers and Wells
# 7  Accountant, chartered public finance                   Schroeder Inc
# 8            Sports development officer  Williams, Williams and Roberts
# 9                Operational researcher                      Yang-Jones
#
#            ssn                                          residence  \
# 0  789-79-7457  35412 Moore Spring Apt. 205\nPort Danaburgh, N...
# ...
